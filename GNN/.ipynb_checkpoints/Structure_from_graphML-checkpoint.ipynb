# %%
pip install networkx pygraphml
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for pygraphml: filename=pygraphml-2.4.2-py2.py3-none-any.whl size=9766 sha256=b49cf0c199acef490e640d28315d919aea125df5bd1083e48de9d13a22c4b544
#   Stored in directory: c:\users\harip\appdata\local\pip\cache\wheels\62\5d\a2\c952cf35b5cab65c333287f61b62f401681c44a8e00a5f3223
# Successfully built pygraphml
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Load the GraphML file
graph = nx.read_graphml('test-large.graphml')

# %%
# Draw the graph
plt.figure(figsize=(10, 10))
nx.draw(graph, with_labels=True, node_size=500, node_color='skyblue', font_size=10, font_color='black', edge_color='gray')
plt.title('Graph Visualization from GraphML')
plt.show()

# %%
# TODO store these x, y, active, neuron_type as a dataset

# %%
# Iterate over nodes to extract features
for node_id, attributes in graph.nodes(data=True):
    x = attributes.get('x', 0)
    y = attributes.get('y', 0)
    active = attributes.get('active', 0)
    neuron_type = attributes.get('type', 'UNKNOWN')
    # Process the features as needed

# %%
x
# Out:
# 99.0

# %%
import h5py

# %%
f = h5py.File('test-large-connected-out.h5','r')

# %%
list(f.keys())
# Out:
#   Cell In[14], line 1
#     (list(f.keys())
#                    ^
# SyntaxError: incomplete input

# %%
len(list(f.keys()))
# Out:
# 1000
